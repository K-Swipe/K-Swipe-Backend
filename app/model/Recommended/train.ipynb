# %%
import warnings

import joblib
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from tqdm import tqdm

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
path = "./data/preprocessing"

busan_spot_info = pd.read_csv("./data/preprocessing/busan_spot_info - final.csv", encoding="cp949")
travel = pd.read_csv("./data/preprocessing/travel.csv")
traveller_master = pd.read_csv("./data/preprocessing/traveller_master.csv")

# %%
def mission_check(travel):
    travel_list = []
    for i in range(len(travel)):
        value = int(travel['TRAVEL_MISSION_CHECK'][i].split(';')[0])
        travel_list.append(value)
    return travel_list


travel['TRAVEL_MISSION_PRIORITY'] = mission_check(travel)
travel = travel[['TRAVEL_ID', 'TRAVELER_ID', 'TRAVEL_MISSION_PRIORITY', 'MVMN_NM']]

# %%
# 캠핑, 스파/온천/성수, 반려동물 동반 여행, 친환경 여행, 등반 여행 삭제
exclude_priorities = [8, 10, 25, 27, 28]
travel = travel[~travel['TRAVEL_MISSION_PRIORITY'].isin(exclude_priorities)]

# %%
# 통합 제안 및 삭제 제안
traveller_master['TRAVEL_MOTIVE_1'] = traveller_master['TRAVEL_MOTIVE_1'].replace(4, 1)
traveller_master['TRAVEL_MOTIVE_1'] = traveller_master['TRAVEL_MOTIVE_1'].replace(6, 2)
traveller_master['TRAVEL_MOTIVE_1'] = traveller_master['TRAVEL_MOTIVE_1'].replace(8, 7)
traveller_master = traveller_master[traveller_master['TRAVEL_MOTIVE_1'] != 10]

# %%
travel_style_columns = ['TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3', 'TRAVEL_STYL_4', 
                        'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7', 'TRAVEL_STYL_8']


traveller_master['TRAVEL_STYL'] = traveller_master[travel_style_columns].mode(axis=1)[0]
traveller_master['TRAVEL_STYL'] = traveller_master['TRAVEL_STYL'].replace({1: 1, 2: 1, 3: 1, 4: 2, 5: 3, 6: 3, 7: 3})


traveller_master = traveller_master[['TRAVELER_ID', 'GENDER', 'AGE_GRP', 'INCOME', 'TRAVEL_STYL', 
                                      'TRAVEL_MOTIVE_1', 'TRAVEL_NUM', 'TRAVEL_COMPANIONS_NUM' ]]

# %%
busan_spot_info = busan_spot_info[['TRAVEL_ID', 'VISIT_AREA_NM', 'SIDO', 'GUNGU', 'VISIT_AREA_TYPE_CD', 'DGSTFN',
                                  'REVISIT_INTENTION', 'RCMDTN_INTENTION', 'RESIDENCE_TIME_MIN', 'REVISIT_YN']].reset_index(drop=True)

# %%
"""Age Group 40대 이상은 40으로 변경"""
traveller_master['AGE_GRP'] = traveller_master['AGE_GRP'].apply(lambda x: 40 if x >= 40 else x)

# %%
"""busan spot info와 traveller_master, travel merge Result: 부산에 여행온 사람들의 정보"""
df = pd.merge(travel, traveller_master, left_on = 'TRAVELER_ID', right_on = 'TRAVELER_ID', how = 'inner')
df = pd.merge(busan_spot_info, df, left_on = 'TRAVEL_ID', right_on = 'TRAVEL_ID', how = 'left')

# %%
"""Preprocessing"""

df["RESIDENCE_TIME_MIN"] = df["RESIDENCE_TIME_MIN"].replace(0, df["RESIDENCE_TIME_MIN"].median())

df['REVISIT_YN'] = df['REVISIT_YN'].replace("N",0)
df['REVISIT_YN'] = df['REVISIT_YN'].replace("Y",1)

df = df.dropna(subset = ['TRAVEL_STYL'])
df = df.reset_index(drop= True)
df = df.dropna(subset = ['TRAVEL_MOTIVE_1'])
df = df.reset_index(drop= True)

# %%
df = df.drop(columns = ["INCOME"])

# %%
"""특정 관광지에 방문한 사람들 중 랜덤으로 한 명을 선택하여 그 사람의 모든 여행 데이터를 새로운 데이터프레임 train_df에 추가합니다"""
df_copy = df.copy()
train_df = pd.DataFrame(columns=df.columns)  

for area in tqdm(df['VISIT_AREA_NM'].unique()):
    area_visitors_df = df_copy[df_copy['VISIT_AREA_NM'] == area]  # 특정 관광지에 방문한 모든 사람의 데이터를 추출
    
    np.random.seed(1103)  # 랜덤 시드 설정
    if area_visitors_df.empty:  # 만약 해당 관광지에 방문한 사람이 없으면
        continue  # 아무 작업도 하지 않고 다음 반복으로 넘어감
    
    random_idx = np.random.randint(len(area_visitors_df))  # 해당 관광지에 방문한 사람 중 랜덤으로 한 명의 인덱스를 생성
    random_visitor_df = area_visitors_df.iloc[[random_idx]]  # 랜덤으로 선택된 사람의 데이터 추출
    travel_id = random_visitor_df.iloc[0, 0]  # 해당 사람의 'TRAVEL_ID' 값을 추출
    
    visitor_trips_df = df_copy[df_copy['TRAVEL_ID'] == travel_id]  # 선택된 사람의 모든 여행 데이터를 추출
    
    df_copy = pd.merge(visitor_trips_df, df_copy, how='outer', indicator=True)  # 원본 데이터프레임과 선택된 사람의 데이터를 병합, 병합 결과를 표시
    df_copy = df_copy.query('_merge == "right_only"').drop(columns=['_merge'])  # 원본 데이터프레임에서 선택된 사람의 데이터를 삭제
    
    train_df = train_df.append(visitor_trips_df, ignore_index=True)  # 선택된 사람의 데이터를 train_df 데이터프레임에 추가
# Out:
# 100%|██████████| 627/627 [00:04<00:00, 132.67it/s]

# %%
while len(df_copy) / len(df) > 0.15:
    np.random.seed(1103)  # 랜덤 시드 설정
    random_idx = np.random.randint(len(df_copy))  # 랜덤 인덱스 생성
    random_visitor = df_copy.iloc[[random_idx]]  # 랜덤으로 선택된 사람의 데이터 추출
    travel_id = random_visitor.iloc[0, 0]  # 해당 사람의 'TRAVEL_ID' 값 추출
    
    visitor_trips = df_copy[df_copy['TRAVEL_ID'] == travel_id]  # 선택된 사람의 모든 여행 데이터 추출

    df_copy = pd.merge(visitor_trips, df_copy, how='outer', indicator=True)  # 원본 데이터프레임과 선택된 사람의 데이터를 병합, 병합 결과를 표시
    df_copy = df_copy.query('_merge == "right_only"').drop(columns=['_merge'])  # 원본 데이터프레임에서 선택된 사람의 데이터를 삭제
    
    train_df = train_df.append(visitor_trips, ignore_index=True)  # 선택된 사람의 데이터를 train_df 데이터프레임에 추가

# %%
new_train = pd.DataFrame(columns = list(train_df.columns) + ['RESIDENCE_TIME_MIN_mean', 'RCMDTN_INTENTION_mean',
                                                          'REVISIT_YN_mean', 'TRAVEL_COMPANIONS_NUM_mean',
                                                          'REVISIT_INTENTION_mean'])


for i in tqdm(list(train_df['VISIT_AREA_NM'].unique())): #유니크한 관광지 목록 중에서
    df2 = train_df[train_df['VISIT_AREA_NM'] == i] # 특정 관광지에 간 모든 사람 뽑아서
    for j in ['RESIDENCE_TIME_MIN', 'RCMDTN_INTENTION', 'REVISIT_YN', 'TRAVEL_COMPANIONS_NUM', 'REVISIT_INTENTION']:
        #체류시간 평균 산출 
        globals()[str(j)+'_mean'] = df2[str(j)]
        globals()[str(j)+'_mean'] = np.mean(globals()[str(j)+'_mean'])
        #데이터프레임에 들어가게 값을 리스트 형태로 변환
        globals()[str(j)+'_mean'] = np.repeat(globals()[str(j)+'_mean'], len(df2)) 
        df2[str(j)+'_mean'] = globals()[str(j)+'_mean']
    #새로운 데이터프레임에 방문지별 평균값 대입
    new_train = pd.concat([new_train, df2], axis = 0)
    
new_train.sort_values(by = ['TRAVEL_ID'], axis = 0, inplace = True)
# Out:
# 100%|██████████| 627/627 [00:00<00:00, 684.99it/s]

# %%
path = r"C:\workspace\Ko-Swipe-ML\data\preprocessing"
new_train.to_csv(path + '/관광지 추천시스템 Trainset.csv', index = False)
df_copy.to_csv(path + '/관광지 추천시스템 Testset.csv', index = False)

# %%
Train = pd.read_csv(path + '/관광지 추천시스템 Trainset.csv')
test = pd.read_csv(path + '/관광지 추천시스템 Testset.csv')

Train.dropna(inplace = True)
Train.reset_index(inplace = True, drop = True )

test.dropna(inplace = True)
test.reset_index(inplace = True, drop = True )

print(Train.shape)
print(test.shape)
# Out:
# (2467, 24)
# (403, 19)

# %%
"""5번 이상 방문한 곳으로만 필터링"""
Train.reset_index(drop = True, inplace= True)

count = pd.DataFrame(Train['VISIT_AREA_NM'].value_counts())
count['places'] = count.index
five_places = list(count[count['VISIT_AREA_NM']>=5]['places']) 
for i in range(len(Train)):
    if Train['VISIT_AREA_NM'][i] not in five_places:
        Train = Train.drop([i], axis = 0)
Train.reset_index(drop = True, inplace = True)

# %%
count_visit5 = pd.DataFrame(Train['VISIT_AREA_NM'].value_counts())

# %%
"""Drop Features"""
Train.drop(['TRAVELER_ID', 'REVISIT_INTENTION', 'RCMDTN_INTENTION','RESIDENCE_TIME_MIN', 'REVISIT_YN'], axis = 1, inplace = True)
test.drop(['TRAVELER_ID', 'REVISIT_INTENTION', 'RCMDTN_INTENTION','RESIDENCE_TIME_MIN', 'REVISIT_YN'], axis = 1, inplace = True)

# %%
"""Change dtype"""
Train['VISIT_AREA_TYPE_CD'] = Train['VISIT_AREA_TYPE_CD'].astype('string')
test['VISIT_AREA_TYPE_CD'] = test['VISIT_AREA_TYPE_CD'].astype('string')

# %%
x_train = Train.drop(['DGSTFN', 'TRAVEL_ID'], axis = 1)
y_train = Train['DGSTFN']

# %%
category_features = ["VISIT_AREA_NM", "SIDO", "GUNGU", "VISIT_AREA_TYPE_CD", "TRAVEL_MISSION_PRIORITY", "AGE_GRP", "GENDER", "MVMN_NM"]

# %%
x_train['TRAVEL_MISSION_PRIORITY'] = x_train['TRAVEL_MISSION_PRIORITY'].astype('int')
x_train['AGE_GRP'] = x_train['AGE_GRP'].astype('int')

# %%
def recall_at_k(recommended_items, relevant_items, k):
    recommended_at_k = recommended_items[:k]
    relevant_at_k = set(recommended_at_k) & set(relevant_items)
    return len(relevant_at_k) / len(relevant_items)

# %%
model = CatBoostRegressor(
    n_estimators=1150,
    max_depth=10,
    subsample=0.9500000000000002,
    colsample_bylevel=0.9500000000000002,
    cat_features=category_features,
    random_state=42,
    verbose=100,
)

model.fit(x_train, y_train)
# Out:
# Learning rate set to 0.040123
# 0:	learn: 0.7903454	total: 171ms	remaining: 3m 16s
# 100:	learn: 0.5806943	total: 3.65s	remaining: 37.9s
# 200:	learn: 0.4766264	total: 7.39s	remaining: 34.9s
# 300:	learn: 0.4022822	total: 11.2s	remaining: 31.6s
# 400:	learn: 0.3439642	total: 15s	remaining: 28s
# 500:	learn: 0.2934957	total: 18.8s	remaining: 24.3s
# 600:	learn: 0.2451566	total: 22.6s	remaining: 20.7s
# 700:	learn: 0.2118319	total: 26.4s	remaining: 16.9s
# 800:	learn: 0.1870518	total: 30.3s	remaining: 13.2s
# 900:	learn: 0.1625723	total: 34s	remaining: 9.4s
# 1000:	learn: 0.1381454	total: 37.7s	remaining: 5.62s
# 1100:	learn: 0.1226152	total: 41.5s	remaining: 1.84s
# 1149:	learn: 0.1155329	total: 43.3s	remaining: 0us

# %%
joblib.dump(model, path + '/catboost_model_B.pkl')
# Out:
# ['C:\\workspace\\Ko-Swipe-ML\\data\\preprocessing/catboost_model_B.pkl']

# %%
path = r"C:\workspace\Ko-Swipe-ML\data\preprocessing"

modelb = joblib.load(path + '/catboost_model_B.pkl')
testb = pd.read_csv(path + '/관광지 추천시스템 Testset.csv')
trainb = pd.read_csv(path + '/관광지 추천시스템 Trainset.csv')

trainb.dropna(inplace = True)
trainb.reset_index(inplace = True, drop = True )

testb.dropna(inplace = True)
testb.reset_index(inplace = True, drop = True )

# %%
X_testb = testb.drop(['DGSTFN'], axis = 1)
y_testb = testb['DGSTFN']

# %%
# 유저정보
user_info = testb[
    [
        "TRAVEL_ID",
        "SIDO",
        "GUNGU",
        "TRAVEL_MISSION_PRIORITY",
        "MVMN_NM",
        "GENDER",
        "AGE_GRP",
        # "INCOME",
        "TRAVEL_STYL",
        "TRAVEL_MOTIVE_1",
        "TRAVEL_NUM",
        "TRAVEL_COMPANIONS_NUM",
    ]
]

# %%
# new_user_info = pd.DataFrame(columns=['TRAVEL_ID', 'TRAVEL_MISSION_PRIORITY', "MVMN_NM", 'GENDER', 'AGE_GRP', 'INCOME',
#                             'TRAVEL_STYL','TRAVEL_MOTIVE_1', 'TRAVEL_NUM', 'TRAVEL_COMPANIONS_NUM', 'sido_gungu_list'])

new_user_info = pd.DataFrame(columns=['TRAVEL_ID', 'TRAVEL_MISSION_PRIORITY', "MVMN_NM", 'GENDER', 'AGE_GRP',
                            'TRAVEL_STYL','TRAVEL_MOTIVE_1', 'TRAVEL_NUM', 'TRAVEL_COMPANIONS_NUM', 'sido_gungu_list'])
for i in tqdm(list(user_info['TRAVEL_ID'].unique())):
    user_info_filtered = user_info[user_info['TRAVEL_ID'] == i]
    userLocations = user_info_filtered[['SIDO', 'GUNGU']] #각 유저별 방문한 시군구 확인
    userLocations.reset_index(drop = True, inplace = True)
    sido_gungu_visit = []
    for j in range(len(userLocations)):
        sido_gungu_visit.append(userLocations['SIDO'][j] + '+' + userLocations['GUNGU'][j])
    sido_gungu_list = list(set(sido_gungu_visit))
    new = user_info_filtered.drop(['SIDO', 'GUNGU'], axis = 1) #기존 시도, 군구 제외하고
    new = new.head(1)
    new['sido_gungu_list'] = str(sido_gungu_list)
    new_user_info = pd.concat([new_user_info, new], axis = 0) #새로운 데이터프레임 생성
# Out:
# 100%|██████████| 155/155 [00:00<00:00, 1067.10it/s]

# %%
new_user_info.reset_index(drop = True, inplace = True)
new_user_info.to_csv(path + '/관광지 추천시스템 Testset_B- 유저 정보.csv', index=False)

# %%
#여행지 정보
info = trainb[['SIDO', 'VISIT_AREA_NM', 'GUNGU','VISIT_AREA_TYPE_CD','RESIDENCE_TIME_MIN_mean', 'RCMDTN_INTENTION_mean',
            'REVISIT_YN_mean', 'TRAVEL_COMPANIONS_NUM_mean', 'REVISIT_INTENTION_mean']]
info.drop_duplicates(['VISIT_AREA_NM'], inplace = True)

# %%
###### 2회 이상 관광한 방문지 리스트 생성
visiting_list = trainb[['VISIT_AREA_NM']] #train set에 있는 방문지에 대해서만 2회 이상 방문하였는지 확인
visiting_list.reset_index(drop = True, inplace = True)
#데이터 전처리
visit_count_df = pd.DataFrame(visiting_list.value_counts(), columns = ['count'])
visit_count_df['VISIT_AREA_NM'] = visit_count_df.index
visit_count_df.reset_index(drop = True, inplace = True)
for i in range(len(visit_count_df)):
    visit_count_df['VISIT_AREA_NM'][i] = str(visit_count_df['VISIT_AREA_NM'][i])
    visit_count_df['VISIT_AREA_NM'][i] = visit_count_df['VISIT_AREA_NM'][i].replace("(","").replace(")","").replace(",","").replace("\''","")
    visit_count_df['VISIT_AREA_NM'][i] = visit_count_df['VISIT_AREA_NM'][i][1:-1]
#5회 이상 적용
visit_count_df = visit_count_df[visit_count_df['count'] >= 5]  
visit_list = list(visit_count_df['VISIT_AREA_NM']) #visit_list에 5회 이상 방문지 리스트

# %%
#방문지가 5회 이상 방문한 관광지 아니면 제거
info.reset_index(drop = True, inplace = True)
for i in tqdm(range(len(info))):
    if info['VISIT_AREA_NM'][i] not in visit_list:
        info = info.drop([i], axis = 0)
info.reset_index(drop = True, inplace = True)
# Out:
# 100%|██████████| 582/582 [00:00<00:00, 10034.72it/s]

# %%
#여행자 정보 저장
info.reset_index(drop = True, inplace = True)
info.to_csv(path + '/관광지 추천시스템 Testset_B- 여행지 정보.csv', index=False)

# %%
user_info = pd.read_csv(path + '/관광지 추천시스템 Testset_B- 유저 정보.csv')
info = pd.read_csv(path + '/관광지 추천시스템 Testset_B- 여행지 정보.csv')

# %%
new_user_info['TRAVEL_MISSION_PRIORITY'] = new_user_info['TRAVEL_MISSION_PRIORITY'].astype('int')
new_user_info['AGE_GRP'] = new_user_info['AGE_GRP'].astype('int')

# %%
import pandas as pd

# Define column lists
# final_columns = [
#     "VISIT_AREA_NM", "SIDO", "GUNGU", "VISIT_AREA_TYPE_CD", "TRAVEL_MISSION_PRIORITY", "MVMN_NM", "GENDER", "AGE_GRP", "INCOME",
#     "TRAVEL_STYL", "TRAVEL_MOTIVE_1", "TRAVEL_NUM", "TRAVEL_COMPANIONS_NUM", 
#     "RESIDENCE_TIME_MIN_mean", "RCMDTN_INTENTION_mean", "REVISIT_YN_mean", "TRAVEL_COMPANIONS_NUM_mean", 
#     "REVISIT_INTENTION_mean"
# ]

# user_columns = [
#     "SIDO", "TRAVEL_MISSION_PRIORITY", "MVMN_NM", "GENDER", "AGE_GRP", "INCOME", "TRAVEL_STYL",
#     "TRAVEL_MOTIVE_1", "TRAVEL_NUM", "TRAVEL_COMPANIONS_NUM"
# ]
final_columns = [
    "VISIT_AREA_NM", "SIDO", "GUNGU", "VISIT_AREA_TYPE_CD", "TRAVEL_MISSION_PRIORITY", "MVMN_NM", "GENDER", "AGE_GRP",
    "TRAVEL_STYL", "TRAVEL_MOTIVE_1", "TRAVEL_NUM", "TRAVEL_COMPANIONS_NUM", 
    "RESIDENCE_TIME_MIN_mean", "RCMDTN_INTENTION_mean", "REVISIT_YN_mean", "TRAVEL_COMPANIONS_NUM_mean", 
    "REVISIT_INTENTION_mean"
]

user_columns = [
    "SIDO", "TRAVEL_MISSION_PRIORITY", "MVMN_NM", "GENDER", "AGE_GRP", "TRAVEL_STYL",
    "TRAVEL_MOTIVE_1", "TRAVEL_NUM", "TRAVEL_COMPANIONS_NUM"
]
features = final_columns

def convert_float_to_int(df):
    float_cols = df.select_dtypes(include=['float']).columns
    
    for col in float_cols:
        df[col] = df[col].astype(int)
    
    return df

def preprocess_places_list(places_list_str):
    """
    Preprocesses the places list string into a list of places.

    Parameters:
    places_list_str (str): String representation of the places list.

    Returns:
    list: A list of places.
    """
    places_list = places_list_str.replace("[", "").replace("]", "").replace("'", "").replace(", ", ",")
    return list(map(str, places_list.split(",")))

def generate_final_df(info, new_user_info, places_list):
    """
    Generates the final DataFrame based on user information and places list.

    Parameters:
    info (DataFrame): DataFrame containing area information.
    new_user_info (DataFrame): DataFrame containing new user information.
    places_list (list): List of places.

    Returns:
    DataFrame: The final DataFrame containing combined user and area information.
    """
    final_df = pd.DataFrame(columns=final_columns)
    
    for place in places_list:
        sido, gungu = map(str, place.split("+"))
        info_df = info[(info["SIDO"] == sido) & (info["GUNGU"] == gungu)].drop(["SIDO"], axis=1).reset_index(drop=True)
        user_data = new_user_info.drop(["sido_gungu_list"], axis=1).values.tolist()[0]
        user_data = [sido] + user_data
        user_df = pd.DataFrame([user_data] * len(info_df), columns=user_columns)
        df = pd.concat([user_df, info_df], axis=1)[features]
        df["VISIT_AREA_TYPE_CD"] = df["VISIT_AREA_TYPE_CD"].astype("string")
        final_df = pd.concat([final_df, df], axis=0)
        
    final_df.reset_index(drop=True, inplace=True)
    final_df.drop_duplicates(["VISIT_AREA_NM"], inplace=True)
    return final_df

def recommend_places(model, final_df):
    """
    Recommends places based on the model's predictions.

    Parameters:
    model: The predictive model.
    final_df (DataFrame): The final DataFrame containing combined user and area information.

    Returns:
    list: List of recommended places.
    """
    final_df = convert_float_to_int(final_df)
    y_pred = model.predict(final_df)
    y_pred_df = pd.DataFrame(y_pred, columns=["y_pred"])
    sorted_df = pd.concat([final_df, y_pred_df], axis=1).sort_values(by="y_pred", ascending=False).iloc[:20]
    return list(sorted_df["VISIT_AREA_NM"])


def generate_user_info_df(final_df):
    """
    Generates a DataFrame containing user information.

    Parameters:
    final_df (DataFrame): The final DataFrame containing combined user and area information.

    Returns:
    DataFrame: DataFrame containing user information.
    """
    return final_df[user_columns]

def main(info, new_user_info, model):
    """
    Main function to generate recommendations and user information.

    Parameters:
    info (DataFrame): DataFrame containing area information.
    new_user_info (DataFrame): DataFrame containing new user information.
    model: The predictive model.

    Returns:
    list: A list containing user information and recommended places.
    """
    
    
    result = []
    places_list_str = new_user_info["sido_gungu_list"].values[0]
    places_list = preprocess_places_list(places_list_str)
    final_df = generate_final_df(info, new_user_info, places_list)
    
    visiting_candidates = recommend_places(model, final_df)
    user_info_df = generate_user_info_df(final_df)
    
    if len(user_info_df) == 0:
        result.append([])
    else:
        rec = user_info_df.iloc[0].to_list()
        rec.append(visiting_candidates)
        result.append(rec)
    
    return result

# %%
new_user_info.drop(['TRAVEL_ID'], axis = 1, inplace = True)

# %%
new_user_info
# Out:
#      TRAVEL_MISSION_PRIORITY MVMN_NM GENDER  AGE_GRP  TRAVEL_STYL  \
# 0                          2     자가용      여       30          2.0
# 1                         23     자가용      남       40          1.0
# 2                          1     자가용      여       40          1.0
# 3                          1  대중교통 등      여       30          1.0
# 4                         21  대중교통 등      여       20          1.0
# ..                       ...     ...    ...      ...          ...
# 150                        6     자가용      여       20          2.0
# 151                       22  대중교통 등      여       30          1.0
# 152                        1     자가용      여       40          1.0
# 153                        6  대중교통 등      여       30          1.0
# 154                        4     자가용      남       20          1.0
#
#      TRAVEL_MOTIVE_1  TRAVEL_NUM  TRAVEL_COMPANIONS_NUM  \
# 0                7.0         3.0                    1.0
# 1                2.0         2.0                    3.0
# 2                1.0        10.0                    1.0
# 3                1.0         6.0                    1.0
# 4                1.0         1.0                    1.0
# ..               ...         ...                    ...
# 150              2.0         1.0                    0.0
# 151              3.0         1.0                    5.0
# 152              3.0         1.0                    3.0
# 153              7.0         2.0                    1.0
# 154              1.0         1.0                    1.0
#
#                               sido_gungu_list
# 0                                  ['부산+사하구']
# 1                       ['부산+기장군', '부산+해운대구']
# 2                                   ['부산+중구']
# 3    ['부산+영도구', '부산+부산진구', '부산+중구', '부산+수영구']
# 4     ['부산+영도구', '부산+사하구', '부산+중구', '부산+수영구']
# ..                                        ...
# 150                                ['부산+수영구']
# 151              ['부산+서구', '부산+중구', '부산+수영구']
# 152                               ['부산+부산진구']
# 153                               ['부산+해운대구']
# 154                                ['부산+수영구']
#
# [155 rows x 9 columns]

# %%
res = []
for i in range(len(new_user_info)):
    try:
        result = main(info, new_user_info.iloc[[i]], modelb)
        res.append(result[0][-1])
    except:
        result = None
        res.append(result)
# Out:
# No objects info loaded
# No objects info loaded
# No objects info loaded
# No objects info loaded

# %%
res
# Out:
# [['감천문화마을', '부산 현대미술관', '을숙도 생태공원', '다대포 해수욕장'],
#  ['부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '해운대 해수욕장',
#   '송정 해수욕장',
#   '동백섬',
#   '더베이101',
#   '부산요트투어',
#   '영화의전당',
#   '수영만 요트경기장',
#   '해운대 전통시장',
#   '벡스코',
#   '해리단길',
#   '죽성드림세트장',
#   '행리단길',
#   '해동용궁사',
#   '씨라이프 부산아쿠아리움',
#   '스카이라인루지 부산'],
#  ['용두산공원',
#   '롯데백화점 광복점',
#   '자갈치시장',
#   '부평깡통시장',
#   '국제시장',
#   'BIFF 광장',
#   '다이아몬드타워',
#   '광복로 패션거리'],
#  ['KT&G상상마당 부산',
#   '피아크',
#   '민락수변공원',
#   '광안리해양레포츠센터',
#   '흰여울문화마을',
#   '국립해양박물관',
#   '태종대',
#   '영도대교',
#   'F1963',
#   '롯데백화점 광복점',
#   '부평깡통시장',
#   '부산시민공원',
#   '롯데백화점 부산본점',
#   '황령산',
#   '전포카페거리',
#   '광복로 패션거리',
#   '서면 미술관',
#   '삼정타워',
#   '용두산공원',
#   '밀락 더 마켓'],
#  ['부평깡통시장',
#   '롯데백화점 광복점',
#   '광복로 패션거리',
#   '국립해양박물관',
#   '흰여울문화마을',
#   '민락수변공원',
#   '밀락 더 마켓',
#   'BIFF 광장',
#   '영도대교',
#   '자갈치시장',
#   '감천문화마을',
#   '국제시장',
#   '용두산공원',
#   '태종대',
#   '광안리해양레포츠센터',
#   '피아크',
#   '부산 현대미술관',
#   '다이아몬드타워',
#   'F1963',
#   '광안리 해수욕장'],
#  ['송도해상케이블카 송도베이스테이션',
#   'KT&G상상마당 부산',
#   '서면 미술관',
#   '황령산',
#   '부산시민공원',
#   '롯데백화점 부산본점',
#   '삼정타워',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '송도 해수욕장',
#   '송도구름산책로',
#   '서면 1번가'],
#  ['죽성드림세트장',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '해동용궁사',
#   '신세계 프리미엄 아웃렛 부산',
#   '스카이라인루지 부산',
#   '아홉산 숲',
#   '롯데월드 어드벤처 부산',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점'],
#  ['민락수변공원',
#   '흰여울문화마을',
#   '국립해양박물관',
#   '벡스코',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '광안리 해수욕장',
#   '태종대',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '밀락 더 마켓',
#   '광안리해양레포츠센터',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '피아크',
#   'F1963',
#   '동백섬',
#   '부산요트투어',
#   '신세계백화점 센텀시티점',
#   '씨라이프 부산아쿠아리움'],
#  ['감천문화마을', '부산 현대미술관', '을숙도 생태공원', '다대포 해수욕장'],
#  ['신세계백화점 센텀시티점',
#   '씨라이프 부산아쿠아리움',
#   '행리단길',
#   '부산요트투어',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '송정 해수욕장',
#   '센텀시티 스파랜드',
#   '벡스코',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '청사포 다릿돌 전망대',
#   '해리단길',
#   '더베이101',
#   '동백섬',
#   '해운대 해수욕장',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['부산 사직종합운동장'],
#  ['서면 미술관',
#   'KT&G상상마당 부산',
#   '전포카페거리',
#   '황령산',
#   'NC백화점 서면점',
#   '롯데백화점 부산본점',
#   '삼정타워',
#   '부산시민공원',
#   '서면 1번가'],
#  ['KT&G상상마당 부산',
#   'NC백화점 서면점',
#   '황령산',
#   '서면 미술관',
#   '롯데백화점 부산본점',
#   '전포카페거리',
#   '부산시민공원',
#   '삼정타워',
#   '서면 1번가'],
#  ['광안리해양레포츠센터',
#   'F1963',
#   '스카이라인루지 부산',
#   '민락수변공원',
#   '죽성드림세트장',
#   '해동용궁사',
#   '롯데월드 어드벤처 부산',
#   '아홉산 숲',
#   '롯데프리미엄아울렛 동부산점',
#   '일광 해수욕장',
#   '광안리 해수욕장',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '밀락 더 마켓',
#   '신세계 프리미엄 아웃렛 부산',
#   '이케아 동부산점'],
#  ['부산요트투어',
#   '벡스코',
#   '씨라이프 부산아쿠아리움',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '수영만 요트경기장',
#   '송정 해수욕장',
#   '동백섬',
#   '해운대 블루라인파크',
#   '더베이101',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '롯데백화점 센텀시티점',
#   '해운대 전통시장',
#   '해리단길'],
#  ['흰여울문화마을',
#   '국립해양박물관',
#   '피아크',
#   '더베이101',
#   '태종대',
#   '벡스코',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '부평깡통시장',
#   '뮤지엄 원',
#   '영도대교',
#   '롯데백화점 광복점',
#   '광복로 패션거리',
#   '수영만 요트경기장',
#   '부산요트투어',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '영화의전당'],
#  ['KT&G상상마당 부산',
#   '서면 미술관',
#   '광안리해양레포츠센터',
#   'F1963',
#   '민락수변공원',
#   '전포카페거리',
#   '롯데백화점 부산본점',
#   '밀락 더 마켓',
#   '삼정타워',
#   '광안리 해수욕장',
#   'NC백화점 서면점',
#   '부산시민공원',
#   '황령산',
#   '서면 1번가'],
#  ['청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '흰여울문화마을',
#   '더베이101',
#   '해운대 해수욕장',
#   '영도대교',
#   '태종대',
#   '동백섬',
#   '국립해양박물관',
#   '송정 해수욕장',
#   '벡스코',
#   '행리단길',
#   '피아크',
#   '부산 시립미술관',
#   '라이언 홀리데이 인 부산',
#   '신세계백화점 센텀시티점',
#   '뮤지엄 원',
#   '영화의전당',
#   '죽성드림세트장',
#   '씨라이프 부산아쿠아리움'],
#  ['롯데백화점 광복점',
#   '부평깡통시장',
#   '광복로 패션거리',
#   '민락수변공원',
#   '용두산공원',
#   '흰여울문화마을',
#   '자갈치시장',
#   'BIFF 광장',
#   '국립해양박물관',
#   '국제시장',
#   '행리단길',
#   '해운대 블루라인파크',
#   '영도대교',
#   '해운대 해수욕장',
#   '청사포 다릿돌 전망대',
#   '신세계백화점 센텀시티점',
#   '송정 해수욕장',
#   '더베이101',
#   '이케아 동부산점',
#   '아홉산 숲'],
#  ['벡스코',
#   '해운대 해수욕장',
#   '송정 해수욕장',
#   '더베이101',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '동백섬',
#   '청사포 다릿돌 전망대',
#   '수영만 요트경기장',
#   '죽성드림세트장',
#   '아홉산 숲',
#   '씨라이프 부산아쿠아리움',
#   '영화의전당',
#   '스카이라인루지 부산',
#   '용두산공원',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '해동용궁사'],
#  ['용두산공원',
#   '부평깡통시장',
#   '롯데백화점 광복점',
#   '자갈치시장',
#   '광복로 패션거리',
#   '다이아몬드타워',
#   '국제시장',
#   'BIFF 광장'],
#  ['송도해상케이블카 송도베이스테이션',
#   '수영만 요트경기장',
#   '부산요트투어',
#   '벡스코',
#   '뮤지엄 원',
#   '다이아몬드타워',
#   '범어사',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '광복로 패션거리',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '신세계백화점 센텀시티점',
#   '용두산공원',
#   '더베이101',
#   '롯데백화점 광복점',
#   '라이언 홀리데이 인 부산',
#   '해운대 해수욕장',
#   '송도 해수욕장',
#   '동백섬'],
#  ['벡스코',
#   '국립해양박물관',
#   '광안리해양레포츠센터',
#   '피아크',
#   '흰여울문화마을',
#   '라이언 홀리데이 인 부산',
#   '더베이101',
#   '민락수변공원',
#   '청사포 다릿돌 전망대',
#   '영도대교',
#   '해운대 블루라인파크',
#   '태종대',
#   '이기대해안산책로',
#   'F1963',
#   '롯데백화점 광복점',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '용두산공원',
#   '부산 시립미술관'],
#  ['F1963', '광안리해양레포츠센터', '민락수변공원', '광안리 해수욕장', '밀락 더 마켓'],
#  ['롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '아홉산 숲',
#   '해동용궁사',
#   '신세계 프리미엄 아웃렛 부산',
#   '롯데월드 어드벤처 부산',
#   '죽성드림세트장',
#   '스카이라인루지 부산',
#   '롯데프리미엄아울렛 동부산점',
#   '일광 해수욕장'],
#  ['감천문화마을',
#   '부산 현대미술관',
#   '을숙도 생태공원',
#   '다대포 해수욕장',
#   '흰여울문화마을',
#   '피아크',
#   '국립해양박물관',
#   '부평깡통시장',
#   '롯데백화점 광복점',
#   '태종대',
#   '영도대교',
#   '광복로 패션거리',
#   '다이아몬드타워',
#   'BIFF 광장',
#   '국제시장',
#   '용두산공원',
#   '자갈치시장'],
#  ['F1963',
#   '벡스코',
#   '광안리해양레포츠센터',
#   '부산 시립미술관',
#   '광안리 해수욕장',
#   '영화의전당',
#   '청사포 다릿돌 전망대',
#   '뮤지엄 원',
#   '더베이101',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '동백섬',
#   '씨라이프 부산아쿠아리움',
#   '수영만 요트경기장',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장',
#   '민락수변공원',
#   '행리단길'],
#  ['청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '더베이101',
#   '벡스코',
#   '부산 시립미술관',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '해운대 해수욕장',
#   '송정 해수욕장',
#   '영화의전당',
#   '부산요트투어',
#   '동백섬',
#   '센텀시티 스파랜드',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '해운대 전통시장',
#   '해리단길',
#   '수영만 요트경기장',
#   '롯데백화점 센텀시티점'],
#  ['스카이라인루지 부산',
#   '롯데월드 어드벤처 부산',
#   '죽성드림세트장',
#   '해동용궁사',
#   '일광 해수욕장',
#   '아홉산 숲',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '이케아 동부산점',
#   '롯데프리미엄아울렛 동부산점'],
#  ['수영만 요트경기장',
#   '흰여울문화마을',
#   '광안리해양레포츠센터',
#   '피아크',
#   '부평깡통시장',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '국립해양박물관',
#   '부산 시립미술관',
#   '롯데백화점 광복점',
#   '청사포 다릿돌 전망대',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '해운대 블루라인파크',
#   '송정 해수욕장',
#   '광복로 패션거리',
#   '해운대 해수욕장',
#   '영화의전당',
#   '영도대교'],
#  None,
#  ['수영만 요트경기장',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '송정 해수욕장',
#   '신세계백화점 센텀시티점',
#   '해운대 블루라인파크',
#   '센텀시티 스파랜드',
#   '뮤지엄 원',
#   '더베이101',
#   '행리단길',
#   '부산 시립미술관',
#   '해운대 해수욕장',
#   '벡스코',
#   '청사포 다릿돌 전망대',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '영화의전당',
#   '롯데백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장'],
#  ['KT&G상상마당 부산',
#   '황령산',
#   '서면 미술관',
#   '부산시민공원',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '롯데백화점 부산본점',
#   '삼정타워',
#   '서면 1번가'],
#  ['전포카페거리',
#   '황령산',
#   '서면 미술관',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '해동용궁사',
#   '을숙도 생태공원',
#   '해운대 블루라인파크',
#   '부산 현대미술관',
#   'KT&G상상마당 부산',
#   '감천문화마을',
#   '죽성드림세트장',
#   '송정 해수욕장',
#   'NC백화점 서면점',
#   '부산 시립미술관',
#   '삼정타워',
#   '부산요트투어',
#   '동백섬',
#   '씨라이프 부산아쿠아리움',
#   '롯데백화점 부산본점'],
#  ['F1963',
#   '광안리해양레포츠센터',
#   '국립해양박물관',
#   '피아크',
#   '흰여울문화마을',
#   '태종대',
#   '밀락 더 마켓',
#   '광안리 해수욕장',
#   '민락수변공원',
#   '영도대교',
#   '용두산공원',
#   '다이아몬드타워',
#   '롯데백화점 광복점',
#   '부평깡통시장',
#   '광복로 패션거리',
#   '자갈치시장',
#   'BIFF 광장',
#   '국제시장'],
#  ['해동용궁사',
#   '죽성드림세트장',
#   '아홉산 숲',
#   '스카이라인루지 부산',
#   '롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점'],
#  ['부산 현대미술관', '을숙도 생태공원', '감천문화마을', '다대포 해수욕장'],
#  ['F1963', '광안리해양레포츠센터', '광안리 해수욕장', '민락수변공원', '밀락 더 마켓'],
#  ['광안리해양레포츠센터',
#   '민락수변공원',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '더베이101',
#   '청사포 다릿돌 전망대',
#   '부산 시립미술관',
#   '용두산공원',
#   '동백섬',
#   '송정 해수욕장',
#   '벡스코',
#   'F1963',
#   '행리단길',
#   '영화의전당',
#   '죽성드림세트장',
#   '신세계백화점 센텀시티점',
#   '뮤지엄 원',
#   '광안리 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '해동용궁사'],
#  ['흰여울문화마을',
#   '태종대',
#   'F1963',
#   '영도대교',
#   '피아크',
#   '국립해양박물관',
#   '광안리 해수욕장',
#   '민락수변공원',
#   '밀락 더 마켓',
#   '광안리해양레포츠센터'],
#  ['광안리해양레포츠센터',
#   'F1963',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '서면 미술관',
#   'KT&G상상마당 부산',
#   '민락수변공원',
#   '삼정타워',
#   '롯데백화점 부산본점',
#   '광안리 해수욕장',
#   '황령산',
#   '부산시민공원',
#   '밀락 더 마켓',
#   '서면 1번가'],
#  ['수영만 요트경기장',
#   '뮤지엄 원',
#   '부산요트투어',
#   'KT&G상상마당 부산',
#   '부산 시립미술관',
#   '씨라이프 부산아쿠아리움',
#   '송정 해수욕장',
#   '영화의전당',
#   '해운대 블루라인파크',
#   '부산시민공원',
#   '벡스코',
#   '서면 미술관',
#   '센텀시티 스파랜드',
#   '청사포 다릿돌 전망대',
#   '황령산',
#   '해운대 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '더베이101',
#   '롯데백화점 부산본점',
#   '동백섬'],
#  ['국립해양박물관',
#   '피아크',
#   '태종대',
#   '흰여울문화마을',
#   '용두산공원',
#   '부평깡통시장',
#   '다이아몬드타워',
#   '광복로 패션거리',
#   '영도대교',
#   '롯데백화점 광복점',
#   '자갈치시장',
#   'BIFF 광장',
#   '국제시장'],
#  ['광안리해양레포츠센터',
#   '흰여울문화마을',
#   'F1963',
#   '피아크',
#   '부산요트투어',
#   '민락수변공원',
#   '국립해양박물관',
#   '뮤지엄 원',
#   '죽성드림세트장',
#   '수영만 요트경기장',
#   '해동용궁사',
#   '광안리 해수욕장',
#   '밀락 더 마켓',
#   '스카이라인루지 부산',
#   '부산 시립미술관',
#   '영화의전당',
#   '송정 해수욕장',
#   '태종대',
#   '해운대 블루라인파크',
#   '아홉산 숲'],
#  ['광안리해양레포츠센터', 'F1963', '민락수변공원', '광안리 해수욕장', '밀락 더 마켓'],
#  ['피아크', '국립해양박물관', '흰여울문화마을', '태종대', '영도대교'],
#  ['KT&G상상마당 부산',
#   '광안리해양레포츠센터',
#   'F1963',
#   '민락수변공원',
#   '부산시민공원',
#   '서면 미술관',
#   '전포카페거리',
#   '황령산',
#   '롯데백화점 부산본점',
#   '밀락 더 마켓',
#   '광안리 해수욕장',
#   'NC백화점 서면점',
#   '삼정타워',
#   '서면 1번가'],
#  ['감천문화마을', '을숙도 생태공원', '다대포 해수욕장', '부산 현대미술관'],
#  ['죽성드림세트장',
#   '이케아 동부산점',
#   '영도대교',
#   '일광 해수욕장',
#   '송도해상케이블카 송도베이스테이션',
#   '송도구름산책로',
#   '송도 해수욕장',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '해운대 블루라인파크',
#   '영화의전당',
#   '아홉산 숲',
#   '흰여울문화마을',
#   '동백섬',
#   '롯데프리미엄아울렛 동부산점',
#   '해운대 해수욕장',
#   '부산 시립미술관',
#   '스카이라인루지 부산',
#   '롯데월드 어드벤처 부산',
#   '라이언 홀리데이 인 부산'],
#  ['부산 시립미술관',
#   '씨라이프 부산아쿠아리움',
#   '흰여울문화마을',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '죽성드림세트장',
#   '수영만 요트경기장',
#   '피아크',
#   '부산요트투어',
#   '더베이101',
#   '해운대 블루라인파크',
#   '송정 해수욕장',
#   '벡스코',
#   '국립해양박물관',
#   '태종대',
#   '아홉산 숲',
#   '동백섬',
#   '스카이라인루지 부산',
#   '영화의전당',
#   '해동용궁사'],
#  ['수영만 요트경기장',
#   '씨라이프 부산아쿠아리움',
#   '라이언 홀리데이 인 부산',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '신세계백화점 센텀시티점',
#   '송정 해수욕장',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장',
#   '동백섬',
#   '벡스코',
#   '뮤지엄 원',
#   '영화의전당',
#   '더베이101',
#   '행리단길',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['죽성드림세트장',
#   '해동용궁사',
#   '롯데월드 어드벤처 부산',
#   '아홉산 숲',
#   '스카이라인루지 부산',
#   '일광 해수욕장',
#   '신세계 프리미엄 아웃렛 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '롯데프리미엄아울렛 동부산점'],
#  ['광안리해양레포츠센터',
#   '벡스코',
#   '라이언 홀리데이 인 부산',
#   'F1963',
#   '민락수변공원',
#   '해운대 해수욕장',
#   '더베이101',
#   '밀락 더 마켓',
#   '영화의전당',
#   '송정 해수욕장',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '씨라이프 부산아쿠아리움',
#   '동백섬',
#   '광안리 해수욕장',
#   '청사포 다릿돌 전망대',
#   '부산요트투어',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '센텀시티 스파랜드'],
#  ['F1963', '광안리해양레포츠센터', '민락수변공원', '밀락 더 마켓', '광안리 해수욕장'],
#  ['F1963',
#   '광안리해양레포츠센터',
#   '부평깡통시장',
#   '광안리 해수욕장',
#   '롯데백화점 광복점',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '수영만 요트경기장',
#   '영화의전당',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '뮤지엄 원',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '아홉산 숲',
#   '부산 시립미술관',
#   '센텀시티 스파랜드',
#   '벡스코',
#   '롯데월드 어드벤처 부산',
#   '광복로 패션거리',
#   '죽성드림세트장'],
#  ['부산 시립미술관',
#   '뮤지엄 원',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '해운대 해수욕장',
#   '영화의전당',
#   '청사포 다릿돌 전망대',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '더베이101',
#   '벡스코',
#   '동백섬',
#   '센텀시티 스파랜드',
#   '씨라이프 부산아쿠아리움',
#   '행리단길',
#   '해리단길',
#   '해운대 전통시장',
#   '신세계백화점 센텀시티점',
#   '롯데백화점 센텀시티점'],
#  ['부평깡통시장',
#   '롯데백화점 광복점',
#   '자갈치시장',
#   'BIFF 광장',
#   '다이아몬드타워',
#   '국제시장',
#   '광복로 패션거리',
#   '용두산공원'],
#  ['수영만 요트경기장',
#   '벡스코',
#   '씨라이프 부산아쿠아리움',
#   '부산요트투어',
#   '청사포 다릿돌 전망대',
#   '뮤지엄 원',
#   '더베이101',
#   '부산 시립미술관',
#   '송정 해수욕장',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '라이언 홀리데이 인 부산',
#   '동백섬',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '신세계백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['서면 미술관',
#   'KT&G상상마당 부산',
#   '황령산',
#   '전포카페거리',
#   '롯데백화점 부산본점',
#   'NC백화점 서면점',
#   '부산시민공원',
#   '삼정타워',
#   '서면 1번가'],
#  ['수영만 요트경기장',
#   '국제시장',
#   '자갈치시장',
#   '용두산공원',
#   'BIFF 광장',
#   '부산요트투어',
#   '광복로 패션거리',
#   '벡스코',
#   '씨라이프 부산아쿠아리움',
#   '다이아몬드타워',
#   '부산 현대미술관',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '감천문화마을',
#   '라이언 홀리데이 인 부산',
#   '영화의전당',
#   '을숙도 생태공원',
#   '롯데백화점 광복점',
#   '부평깡통시장',
#   '신세계백화점 센텀시티점'],
#  ['광안리해양레포츠센터',
#   '해운대 블루라인파크',
#   'KT&G상상마당 부산',
#   'F1963',
#   '해운대 해수욕장',
#   '송정 해수욕장',
#   '수영만 요트경기장',
#   '뮤지엄 원',
#   '민락수변공원',
#   '더베이101',
#   '부산요트투어',
#   '밀락 더 마켓',
#   '신세계백화점 센텀시티점',
#   '동백섬',
#   '부산 시립미술관',
#   '씨라이프 부산아쿠아리움',
#   '부산시민공원',
#   '서면 미술관',
#   '황령산',
#   '광안리 해수욕장'],
#  ['벡스코',
#   '더베이101',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '해운대 전통시장',
#   '청사포 다릿돌 전망대',
#   '영화의전당',
#   '동백섬',
#   '부산요트투어',
#   '롯데백화점 센텀시티점',
#   '뮤지엄 원',
#   '씨라이프 부산아쿠아리움',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '부산 시립미술관',
#   '해리단길',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장'],
#  ['아홉산 숲',
#   '죽성드림세트장',
#   '스카이라인루지 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '롯데월드 어드벤처 부산',
#   '해동용궁사',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산'],
#  ['광안리해양레포츠센터',
#   '죽성드림세트장',
#   'F1963',
#   '광안리 해수욕장',
#   '해동용궁사',
#   '아홉산 숲',
#   '민락수변공원',
#   '밀락 더 마켓',
#   '스카이라인루지 부산',
#   '일광 해수욕장',
#   '롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '롯데프리미엄아울렛 동부산점'],
#  ['청사포 다릿돌 전망대',
#   '죽성드림세트장',
#   '라이언 홀리데이 인 부산',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '더베이101',
#   '해동용궁사',
#   '벡스코',
#   '행리단길',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '동백섬',
#   '용두산공원',
#   '이케아 동부산점',
#   '다이아몬드타워',
#   '신세계백화점 센텀시티점',
#   '송정 해수욕장',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '부산요트투어',
#   '해리단길'],
#  ['민락수변공원', '광안리해양레포츠센터', '광안리 해수욕장', '밀락 더 마켓', 'F1963', '초량 차이나타운'],
#  ['씨라이프 부산아쿠아리움',
#   '수영만 요트경기장',
#   '뮤지엄 원',
#   '부산요트투어',
#   '부산 시립미술관',
#   '센텀시티 스파랜드',
#   '영화의전당',
#   '신세계백화점 센텀시티점',
#   '벡스코',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '동백섬',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '롯데백화점 센텀시티점',
#   '라이언 홀리데이 인 부산',
#   '해리단길',
#   '해운대 전통시장'],
#  ['수영만 요트경기장',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '벡스코',
#   '라이언 홀리데이 인 부산',
#   '해운대 해수욕장',
#   '영화의전당',
#   '행리단길',
#   '롯데백화점 센텀시티점',
#   '더베이101',
#   '송정 해수욕장',
#   '신세계백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장',
#   '해운대 블루라인파크',
#   '동백섬',
#   '청사포 다릿돌 전망대',
#   '센텀시티 스파랜드'],
#  None,
#  ['해운대 블루라인파크',
#   '부산 시립미술관',
#   '해운대 해수욕장',
#   '동백섬',
#   '수영만 요트경기장',
#   '라이언 홀리데이 인 부산',
#   '벡스코',
#   '뮤지엄 원',
#   '영화의전당',
#   '부산요트투어',
#   '신세계백화점 센텀시티점',
#   '더베이101',
#   '송정 해수욕장',
#   '센텀시티 스파랜드',
#   '씨라이프 부산아쿠아리움',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['광안리해양레포츠센터',
#   'KT&G상상마당 부산',
#   'F1963',
#   '황령산',
#   '서면 미술관',
#   '민락수변공원',
#   '전포카페거리',
#   '밀락 더 마켓',
#   '부산시민공원',
#   'NC백화점 서면점',
#   '광안리 해수욕장',
#   '롯데백화점 부산본점',
#   '삼정타워',
#   '서면 1번가'],
#  ['황령산',
#   'KT&G상상마당 부산',
#   '부산시민공원',
#   '서면 미술관',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '삼정타워',
#   '롯데백화점 부산본점',
#   '서면 1번가'],
#  ['피아크',
#   '광안리해양레포츠센터',
#   '흰여울문화마을',
#   'F1963',
#   '국립해양박물관',
#   '광안리 해수욕장',
#   '태종대',
#   '민락수변공원',
#   '영도대교',
#   '밀락 더 마켓'],
#  None,
#  ['광안리해양레포츠센터',
#   'F1963',
#   '벡스코',
#   '민락수변공원',
#   '뮤지엄 원',
#   '해운대 해수욕장',
#   '수영만 요트경기장',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '부산요트투어',
#   '동백섬',
#   '밀락 더 마켓',
#   '더베이101',
#   '행리단길',
#   '광안리 해수욕장',
#   '영화의전당',
#   '센텀시티 스파랜드'],
#  ['청사포 다릿돌 전망대',
#   '라이언 홀리데이 인 부산',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '행리단길',
#   '해운대 해수욕장',
#   '신세계백화점 센텀시티점',
#   '동백섬',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '영화의전당',
#   '더베이101',
#   '해운대 전통시장',
#   '해리단길',
#   '초량 차이나타운',
#   '벡스코',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '센텀시티 스파랜드',
#   '수영만 요트경기장'],
#  ['씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '수영만 요트경기장',
#   '뮤지엄 원',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장',
#   '동백섬',
#   '부산 시립미술관',
#   '롯데백화점 센텀시티점',
#   '부산요트투어',
#   '송정 해수욕장',
#   '영화의전당',
#   '더베이101',
#   '청사포 다릿돌 전망대',
#   '해리단길',
#   '해운대 블루라인파크',
#   '해운대 전통시장',
#   '벡스코',
#   '라이언 홀리데이 인 부산'],
#  None,
#  ['부산 아시아드 주경기장',
#   '더베이101',
#   '수영만 요트경기장',
#   '영화의전당',
#   '씨라이프 부산아쿠아리움',
#   '라이언 홀리데이 인 부산',
#   '청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '뮤지엄 원',
#   '동백섬',
#   '부산아시아드 보조경기장',
#   '부산 시립미술관',
#   '행리단길',
#   '부산요트투어',
#   '신세계백화점 센텀시티점',
#   '해운대 해수욕장',
#   '벡스코',
#   '송정 해수욕장',
#   '해리단길',
#   '해운대 전통시장'],
#  ['죽성드림세트장',
#   '스카이라인루지 부산',
#   '아홉산 숲',
#   '해동용궁사',
#   '롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점'],
#  ['해동용궁사',
#   '아홉산 숲',
#   '죽성드림세트장',
#   '롯데프리미엄아울렛 동부산점',
#   '일광 해수욕장',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '롯데월드 어드벤처 부산',
#   '이케아 동부산점',
#   '스카이라인루지 부산'],
#  ['뮤지엄 원',
#   '동백섬',
#   '부산 시립미술관',
#   '송정 해수욕장',
#   '더베이101',
#   '벡스코',
#   '수영만 요트경기장',
#   '해운대 해수욕장',
#   '씨라이프 부산아쿠아리움',
#   '부산요트투어',
#   '해운대 블루라인파크',
#   '신세계백화점 센텀시티점',
#   '영화의전당',
#   '청사포 다릿돌 전망대',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '라이언 홀리데이 인 부산',
#   '롯데백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장'],
#  ['해운대 블루라인파크',
#   '해운대 해수욕장',
#   '벡스코',
#   '아홉산 숲',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '청사포 다릿돌 전망대',
#   '송정 해수욕장',
#   '더베이101',
#   '씨라이프 부산아쿠아리움',
#   '동백섬',
#   '부산요트투어',
#   '죽성드림세트장',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '수영만 요트경기장',
#   '행리단길',
#   '해동용궁사',
#   '스카이라인루지 부산',
#   '센텀시티 스파랜드'],
#  ['청사포 다릿돌 전망대',
#   '더베이101',
#   'F1963',
#   '일광 해수욕장',
#   '해운대 블루라인파크',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '이케아 동부산점',
#   '영화의전당',
#   '해운대 해수욕장',
#   '뮤지엄 원',
#   '동백섬',
#   '해동용궁사',
#   '수영만 요트경기장',
#   '신세계백화점 센텀시티점',
#   '죽성드림세트장',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '아홉산 숲'],
#  ['해운대 블루라인파크',
#   '더베이101',
#   '송정 해수욕장',
#   '부산요트투어',
#   '수영만 요트경기장',
#   '뮤지엄 원',
#   '해운대 해수욕장',
#   '부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '벡스코',
#   '동백섬',
#   '영화의전당',
#   '행리단길',
#   '센텀시티 스파랜드',
#   '라이언 홀리데이 인 부산',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['KT&G상상마당 부산',
#   '전포카페거리',
#   '롯데백화점 부산본점',
#   '황령산',
#   '씨라이프 부산아쿠아리움',
#   '서면 미술관',
#   '수영만 요트경기장',
#   '부산요트투어',
#   '부산시민공원',
#   '뮤지엄 원',
#   'NC백화점 서면점',
#   '삼정타워',
#   '신세계백화점 센텀시티점',
#   '벡스코',
#   '부산 시립미술관',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '동백섬',
#   '해운대 블루라인파크',
#   '더베이101'],
#  ['흰여울문화마을', '국립해양박물관', '피아크', '태종대', '영도대교'],
#  ['광안리해양레포츠센터',
#   '수영만 요트경기장',
#   'F1963',
#   '동백섬',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '뮤지엄 원',
#   '송정 해수욕장',
#   '벡스코',
#   '부산 시립미술관',
#   '영화의전당',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '신세계백화점 센텀시티점',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '민락수변공원',
#   '롯데백화점 센텀시티점',
#   '해운대 해수욕장',
#   '광안리 해수욕장'],
#  ['국립해양박물관',
#   '흰여울문화마을',
#   '영도대교',
#   '태종대',
#   '광복로 패션거리',
#   '롯데백화점 광복점',
#   '피아크',
#   '부평깡통시장',
#   '용두산공원',
#   '다이아몬드타워',
#   '국제시장',
#   'BIFF 광장',
#   '자갈치시장'],
#  ['수영만 요트경기장',
#   '씨라이프 부산아쿠아리움',
#   '해운대 해수욕장',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '더베이101',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '뮤지엄 원',
#   '청사포 다릿돌 전망대',
#   '부산 시립미술관',
#   '센텀시티 스파랜드',
#   '벡스코',
#   '해리단길',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '해운대 전통시장',
#   '영화의전당',
#   '롯데백화점 센텀시티점'],
#  ['벡스코',
#   '청사포 다릿돌 전망대',
#   '부산요트투어',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '더베이101',
#   '송정 해수욕장',
#   '행리단길',
#   '부산 시립미술관',
#   '동백섬',
#   '수영만 요트경기장',
#   '뮤지엄 원',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '신세계백화점 센텀시티점',
#   '씨라이프 부산아쿠아리움',
#   '센텀시티 스파랜드',
#   '해운대 전통시장',
#   '해리단길',
#   '롯데백화점 센텀시티점'],
#  ['영도대교',
#   '태종대',
#   '피아크',
#   '국립해양박물관',
#   '용두산공원',
#   '다이아몬드타워',
#   '흰여울문화마을',
#   '국제시장',
#   '부평깡통시장',
#   '자갈치시장',
#   'BIFF 광장',
#   '롯데백화점 광복점',
#   '광복로 패션거리'],
#  ['해운대 해수욕장',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '청사포 다릿돌 전망대',
#   '벡스코',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '더베이101',
#   '동백섬',
#   '부산요트투어',
#   '영화의전당',
#   '수영만 요트경기장',
#   '라이언 홀리데이 인 부산',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '해운대 전통시장',
#   '해리단길',
#   '롯데백화점 센텀시티점'],
#  ['롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '이케아 동부산점',
#   '죽성드림세트장',
#   '신세계 프리미엄 아웃렛 부산',
#   '스카이라인루지 부산',
#   '해동용궁사',
#   '아홉산 숲',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점'],
#  ['F1963',
#   '광안리해양레포츠센터',
#   '벡스코',
#   '민락수변공원',
#   '해운대 블루라인파크',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '수영만 요트경기장',
#   '영화의전당',
#   '해운대 해수욕장',
#   '부산요트투어',
#   '송정 해수욕장',
#   '동백섬',
#   '신세계백화점 센텀시티점',
#   '광안리 해수욕장',
#   '더베이101',
#   '청사포 다릿돌 전망대',
#   '밀락 더 마켓',
#   '라이언 홀리데이 인 부산',
#   '행리단길'],
#  ['송도해상케이블카 송도베이스테이션', '송도구름산책로', '송도 해수욕장'],
#  ['신세계백화점 센텀시티점',
#   '송정 해수욕장',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '행리단길',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '더베이101',
#   '해운대 해수욕장',
#   '동백섬',
#   '센텀시티 스파랜드',
#   '영화의전당',
#   '벡스코',
#   '라이언 홀리데이 인 부산',
#   '청사포 다릿돌 전망대',
#   '롯데백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장'],
#  ['전포카페거리',
#   'KT&G상상마당 부산',
#   'NC백화점 서면점',
#   '삼정타워',
#   '롯데백화점 부산본점',
#   '서면 미술관',
#   '황령산',
#   '부산시민공원',
#   '서면 1번가'],
#  ['영도대교', '태종대', '피아크', '국립해양박물관', '흰여울문화마을'],
#  ['KT&G상상마당 부산',
#   '부산 아시아드 주경기장',
#   '더베이101',
#   '수영만 요트경기장',
#   '청사포 다릿돌 전망대',
#   '씨라이프 부산아쿠아리움',
#   '뮤지엄 원',
#   '부산시민공원',
#   '해운대 블루라인파크',
#   '황령산',
#   '해운대 해수욕장',
#   '부산아시아드 보조경기장',
#   '영화의전당',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '부산요트투어',
#   '부산 시립미술관',
#   '동백섬',
#   '서면 미술관',
#   '벡스코'],
#  ['씨라이프 부산아쿠아리움',
#   '수영만 요트경기장',
#   '신세계백화점 센텀시티점',
#   '뮤지엄 원',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '부산요트투어',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '송정 해수욕장',
#   '벡스코',
#   '동백섬',
#   '더베이101',
#   '센텀시티 스파랜드',
#   '해운대 해수욕장',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['서면 미술관',
#   '광안리해양레포츠센터',
#   'F1963',
#   '전포카페거리',
#   '민락수변공원',
#   '롯데백화점 부산본점',
#   'KT&G상상마당 부산',
#   '광안리 해수욕장',
#   '삼정타워',
#   '밀락 더 마켓',
#   'NC백화점 서면점',
#   '부산시민공원',
#   '황령산',
#   '서면 1번가'],
#  ['수영만 요트경기장',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '부산요트투어',
#   '뮤지엄 원',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '라이언 홀리데이 인 부산',
#   '청사포 다릿돌 전망대',
#   '센텀시티 스파랜드',
#   '동백섬',
#   '해운대 해수욕장',
#   '신세계백화점 센텀시티점',
#   '벡스코',
#   '영화의전당',
#   '더베이101',
#   '행리단길',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['벡스코',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '부산요트투어',
#   '더베이101',
#   '수영만 요트경기장',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '송정 해수욕장',
#   '영화의전당',
#   '씨라이프 부산아쿠아리움',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '동백섬',
#   '청사포 다릿돌 전망대',
#   '신세계백화점 센텀시티점',
#   '센텀시티 스파랜드',
#   '해운대 전통시장',
#   '해리단길',
#   '롯데백화점 센텀시티점'],
#  ['광안리해양레포츠센터',
#   '벡스코',
#   'F1963',
#   '민락수변공원',
#   '해운대 해수욕장',
#   '뮤지엄 원',
#   '송정 해수욕장',
#   '더베이101',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '동백섬',
#   '청사포 다릿돌 전망대',
#   '수영만 요트경기장',
#   '밀락 더 마켓',
#   '영화의전당',
#   '부산요트투어',
#   '라이언 홀리데이 인 부산',
#   '씨라이프 부산아쿠아리움',
#   '행리단길',
#   '신세계백화점 센텀시티점'],
#  ['황령산',
#   '부산시민공원',
#   'KT&G상상마당 부산',
#   '서면 미술관',
#   '삼정타워',
#   '롯데백화점 부산본점',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '서면 1번가'],
#  ['청사포 다릿돌 전망대',
#   '더베이101',
#   '해운대 블루라인파크',
#   '동백섬',
#   '해운대 해수욕장',
#   '민락수변공원',
#   'F1963',
#   '광안리해양레포츠센터',
#   '신세계백화점 센텀시티점',
#   '수영만 요트경기장',
#   '송정 해수욕장',
#   '행리단길',
#   '광안리 해수욕장',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '부산 시립미술관',
#   '벡스코',
#   '뮤지엄 원',
#   '씨라이프 부산아쿠아리움',
#   '부산요트투어'],
#  ['흰여울문화마을', '태종대', '국립해양박물관', '피아크', '영도대교'],
#  ['광안리해양레포츠센터', '밀락 더 마켓', 'F1963', '민락수변공원', '광안리 해수욕장'],
#  ['벡스코',
#   '청사포 다릿돌 전망대',
#   '씨라이프 부산아쿠아리움',
#   '부산요트투어',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '부산 시립미술관',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '동백섬',
#   '더베이101',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '해운대 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '신세계백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['해운대 해수욕장',
#   '해운대 블루라인파크',
#   '더베이101',
#   '광안리해양레포츠센터',
#   '민락수변공원',
#   '청사포 다릿돌 전망대',
#   '벡스코',
#   '송정 해수욕장',
#   '동백섬',
#   'F1963',
#   '부산 시립미술관',
#   '신세계백화점 센텀시티점',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '영화의전당',
#   '광안리 해수욕장',
#   '밀락 더 마켓',
#   '뮤지엄 원',
#   '수영만 요트경기장',
#   '부산요트투어'],
#  ['KT&G상상마당 부산',
#   '전포카페거리',
#   '서면 미술관',
#   '롯데백화점 부산본점',
#   '삼정타워',
#   '황령산',
#   'NC백화점 서면점',
#   '부산시민공원',
#   '서면 1번가'],
#  ['광안리해양레포츠센터', '광안리 해수욕장', 'F1963', '밀락 더 마켓', '민락수변공원'],
#  ['F1963',
#   '흰여울문화마을',
#   '벡스코',
#   '태종대',
#   '피아크',
#   '광안리해양레포츠센터',
#   '뮤지엄 원',
#   '아홉산 숲',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '영화의전당',
#   '청사포 다릿돌 전망대',
#   '송정 해수욕장',
#   '부산요트투어',
#   '수영만 요트경기장',
#   '국립해양박물관',
#   '더베이101',
#   '해운대 블루라인파크',
#   '스카이라인루지 부산',
#   '센텀시티 스파랜드'],
#  ['F1963',
#   '국립해양박물관',
#   '피아크',
#   '영도대교',
#   '태종대',
#   '흰여울문화마을',
#   '광안리해양레포츠센터',
#   '민락수변공원',
#   '광안리 해수욕장',
#   '밀락 더 마켓'],
#  ['민락수변공원', '밀락 더 마켓', 'F1963', '광안리 해수욕장', '광안리해양레포츠센터'],
#  ['광안리해양레포츠센터',
#   '수영만 요트경기장',
#   '민락수변공원',
#   'F1963',
#   '부산요트투어',
#   '용두산공원',
#   '씨라이프 부산아쿠아리움',
#   '밀락 더 마켓',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '신세계백화점 센텀시티점',
#   '벡스코',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '롯데백화점 센텀시티점',
#   '송정 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '동백섬',
#   '광안리 해수욕장'],
#  ['민락수변공원', '광안리해양레포츠센터', 'F1963', '밀락 더 마켓', '광안리 해수욕장'],
#  ['해운대 블루라인파크',
#   '벡스코',
#   '해운대 해수욕장',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '송정 해수욕장',
#   '부산 시립미술관',
#   '씨라이프 부산아쿠아리움',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '영화의전당',
#   '부산요트투어',
#   '행리단길',
#   '수영만 요트경기장',
#   '센텀시티 스파랜드',
#   '신세계백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장',
#   '롯데백화점 센텀시티점'],
#  ['광안리해양레포츠센터',
#   'F1963',
#   '민락수변공원',
#   '밀락 더 마켓',
#   '광안리 해수욕장',
#   '부산요트투어',
#   '센텀시티 스파랜드',
#   '라이언 홀리데이 인 부산',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '영화의전당',
#   '수영만 요트경기장',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '벡스코',
#   '동백섬',
#   '행리단길',
#   '해운대 해수욕장',
#   '청사포 다릿돌 전망대'],
#  ['감천문화마을', '을숙도 생태공원', '부산 현대미술관', '다대포 해수욕장'],
#  ['감천문화마을',
#   'KT&G상상마당 부산',
#   '황령산',
#   '전포카페거리',
#   '을숙도 생태공원',
#   '롯데백화점 부산본점',
#   '흰여울문화마을',
#   '부산 현대미술관',
#   '다대포 해수욕장',
#   '피아크',
#   '국립해양박물관',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '더베이101',
#   '영도대교',
#   '부산시민공원',
#   '부산 시립미술관',
#   '송정 해수욕장'],
#  ['광안리해양레포츠센터', 'F1963', '밀락 더 마켓', '민락수변공원', '광안리 해수욕장'],
#  ['청사포 다릿돌 전망대',
#   '광안리해양레포츠센터',
#   '벡스코',
#   '수영만 요트경기장',
#   '라이언 홀리데이 인 부산',
#   'F1963',
#   '더베이101',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '영화의전당',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '부산 시립미술관',
#   '민락수변공원',
#   '센텀시티 스파랜드',
#   '동백섬',
#   '행리단길',
#   '신세계백화점 센텀시티점'],
#  ['수영만 요트경기장',
#   '더베이101',
#   '행리단길',
#   '청사포 다릿돌 전망대',
#   '해운대 블루라인파크',
#   '부산요트투어',
#   '벡스코',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '신세계백화점 센텀시티점',
#   '씨라이프 부산아쿠아리움',
#   '해운대 해수욕장',
#   '라이언 홀리데이 인 부산',
#   '영화의전당',
#   '동백섬',
#   '부산 시립미술관',
#   '해운대 전통시장',
#   '센텀시티 스파랜드',
#   '해리단길',
#   '롯데백화점 센텀시티점'],
#  ['더베이101',
#   '수영만 요트경기장',
#   '송정 해수욕장',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '벡스코',
#   '동백섬',
#   '청사포 다릿돌 전망대',
#   '뮤지엄 원',
#   '씨라이프 부산아쿠아리움',
#   '부산요트투어',
#   '부산 시립미술관',
#   '영화의전당',
#   '라이언 홀리데이 인 부산',
#   '센텀시티 스파랜드',
#   '신세계백화점 센텀시티점',
#   '행리단길',
#   '롯데백화점 센텀시티점',
#   '해운대 전통시장',
#   '해리단길'],
#  ['죽성드림세트장',
#   '아홉산 숲',
#   '롯데월드 어드벤처 부산',
#   '일광 해수욕장',
#   '스카이라인루지 부산',
#   '수영만 요트경기장',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '해동용궁사',
#   '부산요트투어',
#   '벡스코',
#   '뮤지엄 원',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '이케아 동부산점',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '송정 해수욕장',
#   '신세계 프리미엄 아웃렛 부산'],
#  ['광안리해양레포츠센터',
#   '용두산공원',
#   '국제시장',
#   'F1963',
#   '자갈치시장',
#   '광복로 패션거리',
#   '민락수변공원',
#   '부평깡통시장',
#   '다이아몬드타워',
#   'BIFF 광장',
#   '롯데백화점 광복점',
#   '광안리 해수욕장',
#   '밀락 더 마켓'],
#  ['죽성드림세트장',
#   '아홉산 숲',
#   '스카이라인루지 부산',
#   '해동용궁사',
#   '롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '일광 해수욕장',
#   '이케아 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '롯데프리미엄아울렛 동부산점'],
#  ['광안리해양레포츠센터',
#   'F1963',
#   '청사포 다릿돌 전망대',
#   '벡스코',
#   '부산 시립미술관',
#   '해운대 해수욕장',
#   '뮤지엄 원',
#   '씨라이프 부산아쿠아리움',
#   '해운대 블루라인파크',
#   '송정 해수욕장',
#   '광안리 해수욕장',
#   '부산요트투어',
#   '센텀시티 스파랜드',
#   '수영만 요트경기장',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '영화의전당',
#   '더베이101',
#   '신세계백화점 센텀시티점',
#   '민락수변공원'],
#  ['용두산공원',
#   '자갈치시장',
#   '롯데백화점 광복점',
#   '부평깡통시장',
#   '국제시장',
#   '황령산',
#   '롯데백화점 부산본점',
#   'KT&G상상마당 부산',
#   'BIFF 광장',
#   '광복로 패션거리',
#   '삼정타워',
#   '서면 미술관',
#   '전포카페거리',
#   'NC백화점 서면점',
#   '부산시민공원',
#   '다이아몬드타워',
#   '서면 1번가'],
#  ['아홉산 숲',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '스카이라인루지 부산',
#   '신세계 프리미엄 아웃렛 부산',
#   '이케아 동부산점',
#   '해동용궁사',
#   '죽성드림세트장',
#   '롯데월드 어드벤처 부산',
#   '일광 해수욕장',
#   '롯데프리미엄아울렛 동부산점'],
#  ['롯데백화점 광복점',
#   '광안리해양레포츠센터',
#   '다이아몬드타워',
#   '용두산공원',
#   '광복로 패션거리',
#   'F1963',
#   '부평깡통시장',
#   '국제시장',
#   '밀락 더 마켓',
#   'BIFF 광장',
#   '광안리 해수욕장',
#   '민락수변공원',
#   '자갈치시장'],
#  ['광안리해양레포츠센터', 'F1963', '광안리 해수욕장', '민락수변공원', '밀락 더 마켓'],
#  ['KT&G상상마당 부산',
#   '서면 미술관',
#   '벡스코',
#   '수영만 요트경기장',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '동백섬',
#   '송정 해수욕장',
#   '영화의전당',
#   '부산 시립미술관',
#   '뮤지엄 원',
#   '씨라이프 부산아쿠아리움',
#   '라이언 홀리데이 인 부산',
#   '부산요트투어',
#   '청사포 다릿돌 전망대',
#   'NC백화점 서면점',
#   '더베이101',
#   '센텀시티 스파랜드',
#   '신세계백화점 센텀시티점',
#   '전포카페거리'],
#  ['죽성드림세트장',
#   'F1963',
#   '일광 해수욕장',
#   '광안리해양레포츠센터',
#   '밀락 더 마켓',
#   '민락수변공원',
#   '이케아 동부산점',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '해동용궁사',
#   '신세계 프리미엄 아웃렛 부산',
#   '스카이라인루지 부산',
#   '롯데프리미엄아울렛 동부산점',
#   '광안리 해수욕장',
#   '아홉산 숲',
#   '롯데월드 어드벤처 부산'],
#  ['광안리해양레포츠센터', 'F1963', '밀락 더 마켓', '민락수변공원', '광안리 해수욕장'],
#  ['부평깡통시장',
#   '용두산공원',
#   '자갈치시장',
#   '롯데백화점 광복점',
#   '광복로 패션거리',
#   '다이아몬드타워',
#   'BIFF 광장',
#   '국제시장'],
#  ['광안리해양레포츠센터', 'F1963', '광안리 해수욕장', '민락수변공원', '밀락 더 마켓'],
#  ['광안리해양레포츠센터', 'F1963', '광안리 해수욕장', '민락수변공원', '밀락 더 마켓'],
#  ['국립해양박물관',
#   '피아크',
#   '흰여울문화마을',
#   '부평깡통시장',
#   '벡스코',
#   '영도대교',
#   '더베이101',
#   '롯데백화점 광복점',
#   '라이언 홀리데이 인 부산',
#   '해운대 블루라인파크',
#   '태종대',
#   '행리단길',
#   '뮤지엄 원',
#   '청사포 다릿돌 전망대',
#   '영화의전당',
#   '부산 시립미술관',
#   '민락수변공원',
#   '해운대 해수욕장',
#   'F1963',
#   '용두산공원'],
#  ['KT&G상상마당 부산',
#   '부산 사직종합운동장',
#   '부산시민공원',
#   '황령산',
#   '서면 미술관',
#   '롯데백화점 부산본점',
#   '전포카페거리',
#   '삼정타워',
#   'NC백화점 서면점',
#   '서면 1번가'],
#  ['뮤지엄 원',
#   '영화의전당',
#   '해운대 해수욕장',
#   '더베이101',
#   '민락수변공원',
#   '부산 시립미술관',
#   '행리단길',
#   '라이언 홀리데이 인 부산',
#   'F1963',
#   '신세계백화점 센텀시티점',
#   '동백섬',
#   '광안리 해수욕장',
#   '씨라이프 부산아쿠아리움',
#   '벡스코',
#   '해운대 블루라인파크',
#   '밀락 더 마켓',
#   '광안리해양레포츠센터',
#   '청사포 다릿돌 전망대',
#   '부산요트투어',
#   '수영만 요트경기장'],
#  ['광안리해양레포츠센터',
#   'KT&G상상마당 부산',
#   'F1963',
#   '서면 미술관',
#   '삼정타워',
#   '민락수변공원',
#   '황령산',
#   '광안리 해수욕장',
#   '롯데백화점 부산본점',
#   '밀락 더 마켓',
#   '부산시민공원',
#   'NC백화점 서면점',
#   '전포카페거리',
#   '서면 1번가'],
#  ['죽성드림세트장',
#   '일광 해수욕장',
#   '스카이라인루지 부산',
#   '해동용궁사',
#   '롯데월드 어드벤처 부산',
#   '롯데 프리미엄 아웃렛 동부산점',
#   '신세계 프리미엄 아웃렛 부산',
#   '이케아 동부산점',
#   '롯데프리미엄아울렛 동부산점',
#   '아홉산 숲'],
#  ['해운대 블루라인파크',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '신세계백화점 센텀시티점',
#   '뮤지엄 원',
#   '벡스코',
#   '송정 해수욕장',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '해운대 해수욕장',
#   '영화의전당',
#   '동백섬',
#   '센텀시티 스파랜드',
#   '라이언 홀리데이 인 부산',
#   '행리단길',
#   '수영만 요트경기장',
#   '부산요트투어',
#   '롯데백화점 센텀시티점',
#   '해리단길',
#   '해운대 전통시장'],
#  ['수영만 요트경기장',
#   '죽성드림세트장',
#   '스카이라인루지 부산',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '롯데월드 어드벤처 부산',
#   '벡스코',
#   '부산 시립미술관',
#   '아홉산 숲',
#   '해동용궁사',
#   '라이언 홀리데이 인 부산',
#   '뮤지엄 원',
#   '부산요트투어',
#   '씨라이프 부산아쿠아리움',
#   '동백섬',
#   '일광 해수욕장',
#   '송정 해수욕장',
#   '영화의전당'],
#  ['청사포 다릿돌 전망대',
#   '광안리해양레포츠센터',
#   '해운대 블루라인파크',
#   '더베이101',
#   '민락수변공원',
#   '씨라이프 부산아쿠아리움',
#   '부산 시립미술관',
#   '신세계백화점 센텀시티점',
#   '뮤지엄 원',
#   '송정 해수욕장',
#   '해운대 해수욕장',
#   'F1963',
#   '동백섬',
#   '영화의전당',
#   '벡스코',
#   '센텀시티 스파랜드',
#   '광안리 해수욕장',
#   '수영만 요트경기장',
#   '밀락 더 마켓',
#   '라이언 홀리데이 인 부산'],
#  ['라이언 홀리데이 인 부산',
#   '부산 시립미술관',
#   '행리단길',
#   '해리단길',
#   '해운대 해수욕장',
#   '청사포 다릿돌 전망대',
#   '부산요트투어',
#   '뮤지엄 원',
#   '더베이101',
#   '수영만 요트경기장',
#   '신세계백화점 센텀시티점',
#   '해운대 블루라인파크',
#   '송정 해수욕장',
#   '롯데백화점 센텀시티점',
#   '벡스코',
#   '해운대 전통시장',
#   '동백섬',
#   '씨라이프 부산아쿠아리움',
#   '영화의전당',
#   '센텀시티 스파랜드'],
#  ['민락수변공원',
#   '광안리해양레포츠센터',
#   'F1963',
#   '라이언 홀리데이 인 부산',
#   '부산 시립미술관',
#   '부산요트투어',
#   '벡스코',
#   '밀락 더 마켓',
#   '청사포 다릿돌 전망대',
#   '행리단길',
#   '뮤지엄 원',
#   '광안리 해수욕장',
#   '수영만 요트경기장',
#   '영화의전당',
#   '해운대 블루라인파크',
#   '해운대 해수욕장',
#   '씨라이프 부산아쿠아리움',
#   '신세계백화점 센텀시티점',
#   '더베이101',
#   '송정 해수욕장'],
#  ['광안리해양레포츠센터', 'F1963', '광안리 해수욕장', '민락수변공원', '밀락 더 마켓'],
#  ['송도해상케이블카 송도베이스테이션',
#   '광안리해양레포츠센터',
#   '송도구름산책로',
#   '송도 해수욕장',
#   '용두산공원',
#   '민락수변공원',
#   'F1963',
#   '다이아몬드타워',
#   'BIFF 광장',
#   '자갈치시장',
#   '밀락 더 마켓',
#   '국제시장',
#   '광안리 해수욕장',
#   '광복로 패션거리',
#   '부평깡통시장',
#   '롯데백화점 광복점'],
#  ['황령산',
#   'KT&G상상마당 부산',
#   '부산시민공원',
#   '서면 미술관',
#   '롯데백화점 부산본점',
#   '전포카페거리',
#   '삼정타워',
#   'NC백화점 서면점',
#   '서면 1번가'],
#  ['수영만 요트경기장',
#   '청사포 다릿돌 전망대',
#   '더베이101',
#   '해운대 해수욕장',
#   '해운대 블루라인파크',
#   '벡스코',
#   '동백섬',
#   '라이언 홀리데이 인 부산',
#   '씨라이프 부산아쿠아리움',
#   '송정 해수욕장',
#   '뮤지엄 원',
#   '부산요트투어',
#   '부산 시립미술관',
#   '영화의전당',
#   '센텀시티 스파랜드',
#   '행리단길',
#   '신세계백화점 센텀시티점',
#   '해운대 전통시장',
#   '해리단길',
#   '롯데백화점 센텀시티점'],
#  ['민락수변공원', '광안리 해수욕장', '광안리해양레포츠센터', '밀락 더 마켓', 'F1963']]
